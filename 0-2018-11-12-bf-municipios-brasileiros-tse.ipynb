# %%
from io import BytesIO
from urllib.request import urlopen
from zipfile import ZipFile

import pandas as pd

# %% [markdown]
# ### Primeiramente, carrego a lista de municípios do tse direto do site oficial

# %%
_ = 'http://www.tse.jus.br/arquivos/tse-lista-de-municipios-do-cadastro-da-justica-eleitoral/at_download/file'

with urlopen(_) as _:
    _ = BytesIO(_.read())

with ZipFile(_) as _:
    with _.open('lista_municipios_justica_eleitoral.txt') as _:
        municipios_tse = pd.read_csv(_, encoding='latin1', sep=';')

municipios_tse.head()
# Out:
#    CÓDIGO  UF          NOME
# 0    1120  AC    ACRELÂNDIA
# 1    1570  AC  ASSIS BRASIL
# 2    1058  AC     BRASILÉIA
# 3    1007  AC        BUJARI
# 4    1015  AC      CAPIXABA

# %% [markdown]
# ### E a lista de múnicipios do ibge, através do repositório git@github:kelvins/Municipios-Brasileiros

# %%
_ = 'https://raw.githubusercontent.com/kelvins/Municipios-Brasileiros/8730f8f9f90a47546f08b216484f5c336a1f531a/municipios_brasileiros.csv'

municipios_brasileiros = pd.read_csv(_)

municipios_brasileiros.head()
# Out:
#    codigo_ibge       nome_municipio  codigo_uf  uf        estado  capital  \
# 0      5200050      Abadia de Goiás         52  GO         Goiás        0
# 1      3100104  Abadia dos Dourados         31  MG  Minas Gerais        0
# 2      5200100            Abadiânia         52  GO         Goiás        0
# 3      3100203               Abaeté         31  MG  Minas Gerais        0
# 4      1500107           Abaetetuba         15  PA          Pará        0
#
#    latitude  longitude
# 0 -16.75730   -49.4412
# 1 -18.48310   -47.3916
# 2 -16.19700   -48.7057
# 3 -19.15510   -45.4444
# 4  -1.72183   -48.8788

# %% [markdown]
# ### Note que ambas as listas contém o mesmo número de rows, desejávelmente seja uma relação de 1 pra 1 em cada lista

# %%
len(municipios_tse), len(municipios_brasileiros)
# Out:
# (5570, 5570)

# %% [markdown]
# ### Indexo cada tabela por (uf, municipio), todos em uppercase

# %%
indexed_tse = (
    municipios_tse
    .set_index(
        municipios_tse
        [['UF', 'NOME']]
        .apply(tuple, axis='columns')
    )
    .sort_index()
)

indexed_tse.head()
# Out:
#                     CÓDIGO  UF          NOME
# (AC, ACRELÂNDIA)      1120  AC    ACRELÂNDIA
# (AC, ASSIS BRASIL)    1570  AC  ASSIS BRASIL
# (AC, BRASILÉIA)       1058  AC     BRASILÉIA
# (AC, BUJARI)          1007  AC        BUJARI
# (AC, CAPIXABA)        1015  AC      CAPIXABA

# %%
indexed_ibge = (
    municipios_brasileiros
    .set_index(
        municipios_brasileiros
        [['uf', 'nome_municipio']]
        .applymap(str.upper)
        .apply(tuple, axis='columns')
    )
    .sort_index()
)

indexed_ibge.head()
# Out:
#                     codigo_ibge nome_municipio  codigo_uf  uf estado  capital  \
# (AC, ACRELÂNDIA)        1200013     Acrelândia         12  AC   Acre        0
# (AC, ASSIS BRASIL)      1200054   Assis Brasil         12  AC   Acre        0
# (AC, BRASILÉIA)         1200104      Brasiléia         12  AC   Acre        0
# (AC, BUJARI)            1200138         Bujari         12  AC   Acre        0
# (AC, CAPIXABA)          1200179       Capixaba         12  AC   Acre        0
#
#                     latitude  longitude
# (AC, ACRELÂNDIA)    -9.82581   -66.8972
# (AC, ASSIS BRASIL) -10.92980   -69.5738
# (AC, BRASILÉIA)    -10.99500   -68.7497
# (AC, BUJARI)        -9.81528   -67.9550
# (AC, CAPIXABA)     -10.56600   -67.6860

# %% [markdown]
# ### Tento o join:

# %%
joined = indexed_tse.join(indexed_ibge, how='inner')
joined.head()
# Out:
#                     CÓDIGO  UF          NOME  codigo_ibge nome_municipio  \
# (AC, ACRELÂNDIA)      1120  AC    ACRELÂNDIA      1200013     Acrelândia
# (AC, ASSIS BRASIL)    1570  AC  ASSIS BRASIL      1200054   Assis Brasil
# (AC, BRASILÉIA)       1058  AC     BRASILÉIA      1200104      Brasiléia
# (AC, BUJARI)          1007  AC        BUJARI      1200138         Bujari
# (AC, CAPIXABA)        1015  AC      CAPIXABA      1200179       Capixaba
#
#                     codigo_uf  uf estado  capital  latitude  longitude
# (AC, ACRELÂNDIA)           12  AC   Acre        0  -9.82581   -66.8972
# (AC, ASSIS BRASIL)         12  AC   Acre        0 -10.92980   -69.5738
# (AC, BRASILÉIA)            12  AC   Acre        0 -10.99500   -68.7497
# (AC, BUJARI)               12  AC   Acre        0  -9.81528   -67.9550
# (AC, CAPIXABA)             12  AC   Acre        0 -10.56600   -67.6860

# %% [markdown]
# ### Ficam faltando:

# %%
len(indexed_tse) - len(joined)
# Out:
# 52

# %% [markdown]
# ### Analisando quais são:

# %%
indexed_tse2 = indexed_tse[~indexed_tse.index.isin(joined.index)]
indexed_tse2
# Out:
#                                  CÓDIGO  UF                       NOME
# (AP, ÁGUA BRANCA DO AMAPARI)       6084  AP     ÁGUA BRANCA DO AMAPARI
# (BA, ARAÇÁS)                      33383  BA                     ARAÇÁS
# (BA, CAEM)                        34010  BA                       CAEM
# (BA, IUIU)                        30660  BA                       IUIU
# (BA, MUQUÉM DO SÃO FRANCISCO)     37460  BA    MUQUÉM DO SÃO FRANCISCO
# (BA, QUINJINGUE)                  38199  BA                 QUINJINGUE
# (BA, SANTA TEREZINHA)             38695  BA            SANTA TEREZINHA
# (BA, SANTO ESTEVÃO)               38750  BA              SANTO ESTEVÃO
# (CE, ITAPAGÉ)                     14273  CE                    ITAPAGÉ
# (ES, ATÍLIO VIVÁCQUA)             56138  ES            ATÍLIO VIVÁCQUA
# (GO, ANHANGÜERA)                  92231  GO                 ANHANGÜERA
# (MG, PASSA VINTE)                 49557  MG                PASSA VINTE
# (MG, PINGO D'ÁGUA)                41360  MG               PINGO D'ÁGUA
# (MG, SEM PEIXE)                   40827  MG                  SEM PEIXE
# (PA, ELDORADO DOS CARAJÁS)         4120  PA       ELDORADO DOS CARAJÁS
# (PA, SANTA ISABEL DO PARÁ)         5290  PA       SANTA ISABEL DO PARÁ
# (PB, QUIXABA)                     21539  PB                    QUIXABA
# (PB, SANTARÉM)                    19666  PB                   SANTARÉM
# (PB, SÃO DOMINGOS DE POMBAL)      19429  PB     SÃO DOMINGOS DE POMBAL
# (PE, BELÉM DE SÃO FRANCISCO)      23310  PE     BELÉM DE SÃO FRANCISCO
# (PE, IGUARACI)                    24376  PE                   IGUARACI
# (PE, SÃO CAITANO)                 25615  PE                SÃO CAITANO
# (PE, SÃO VICENTE FERRÉR)          25755  PE         SÃO VICENTE FERRÉR
# (PI, LUIS CORREIA)                11134  PI               LUIS CORREIA
# (PR, ANTONIO OLINTO)              74233  PR             ANTONIO OLINTO
# (PR, SANTO ANTONIO DO CAIUÁ)      78611  PR     SANTO ANTONIO DO CAIUÁ
# (RJ, TRAJANO DE MORAIS)           59170  RJ          TRAJANO DE MORAIS
# (RN, ASSÚ)                        16039  RN                       ASSÚ
# (RN, BOA SAÚDE)                   17035  RN                  BOA SAÚDE
# (RN, CAMPO GRANDE)                16250  RN               CAMPO GRANDE
# (RN, OLHO D'ÁGUA DO BORGES)       17671  RN      OLHO D'ÁGUA DO BORGES
# (RO, ALTA FLORESTA DO OESTE)        310  RO     ALTA FLORESTA DO OESTE
# (RO, ALVORADA DO OESTE)             337  RO          ALVORADA DO OESTE
# (RO, ESPIGÃO DO OESTE)              256  RO           ESPIGÃO DO OESTE
# (RO, MACHADINHO DO OESTE)           396  RO        MACHADINHO DO OESTE
# (RO, NOVA BRASILÂNDIA DO OESTE)     370  RO  NOVA BRASILÂNDIA DO OESTE
# (RO, SANTA LUZIA DO OESTE)          353  RO       SANTA LUZIA DO OESTE
# (RO, SÃO FELIPE DO OESTE)           710  RO        SÃO FELIPE DO OESTE
# (RS, SANTANA DO LIVRAMENTO)       88455  RS      SANTANA DO LIVRAMENTO
# (SC, GRÃO-PARÁ)                   81191  SC                  GRÃO-PARÁ
# (SC, LAURO MÜLLER)                81892  SC               LAURO MÜLLER
# (SC, LUÍS ALVES)                  81973  SC                 LUÍS ALVES
# (SC, PRESIDENTE CASTELO BRANCO)   82732  SC  PRESIDENTE CASTELO BRANCO
# (SC, SÃO CRISTÓVÃO DO SUL)        80942  SC       SÃO CRISTÓVÃO DO SUL
# (SE, GRACCHO CARDOSO)             31518  SE            GRACCHO CARDOSO
# (SP, BIRITIBA MIRIM)              62316  SP             BIRITIBA MIRIM
# (SP, FLORÍNEA)                    64238  SP                   FLORÍNEA
# (SP, GUAIMBÉ)                     64475  SP                    GUAIMBÉ
# (SP, ITAOCA)                      61603  SP                     ITAOCA
# (SP, SÃO LUÍS DO PARAITINGA)      71013  SP     SÃO LUÍS DO PARAITINGA
# (TO, COUTO DE MAGALHÃES)          93211  TO         COUTO DE MAGALHÃES
# (TO, SÃO VALÉRIO DA NATIVIDADE)   92681  TO  SÃO VALÉRIO DA NATIVIDADE

# %%
indexed_ibge2 = indexed_ibge[~indexed_ibge.index.isin(joined.index)]
indexed_ibge2
# Out:
#                                      codigo_ibge  \
# (AP, PEDRA BRANCA DO AMAPARI)            1600154
# (BA, ARAÇAS)                             2902054
# (BA, CAÉM)                               2905107
# (BA, IUIÚ)                               2917334
# (BA, MUQUÉM DE SÃO FRANCISCO)            2922250
# (BA, QUIJINGUE)                          2925907
# (BA, SANTA TERESINHA)                    2928505
# (BA, SANTO ESTÊVÃO)                      2928802
# (CE, ITAPAJÉ)                            2306306
# (ES, ATILIO VIVACQUA)                    3200706
# (GO, ANHANGUERA)                         5201207
# (MG, PASSA-VINTE)                        3147808
# (MG, PINGO-D'ÁGUA)                       3150539
# (MG, SEM-PEIXE)                          3165560
# (PA, ELDORADO DO CARAJÁS)                1502954
# (PA, SANTA IZABEL DO PARÁ)               1506500
# (PB, JOCA CLAUDINO)                      2513653
# (PB, QUIXABÁ)                            2512606
# (PB, SÃO DOMINGOS)                       2513968
# (PE, BELÉM DO SÃO FRANCISCO)             2601607
# (PE, IGUARACY)                           2606903
# (PE, SÃO CAETANO)                        2613107
# (PE, SÃO VICENTE FERRER)                 2613800
# (PI, LUÍS CORREIA)                       2205706
# (PR, ANTÔNIO OLINTO)                     4101309
# (PR, SANTO ANTÔNIO DO CAIUÁ)             4124202
# (RJ, TRAJANO DE MORAES)                  3305901
# (RN, AUGUSTO SEVERO (CAMPO GRANDE))      2401305
# (RN, AÇU)                                2400208
# (RN, JANUÁRIO CICCO (BOA SAÚDE))         2405306
# (RN, OLHO-D'ÁGUA DO BORGES)              2408409
# (RO, ALTA FLORESTA D'OESTE)              1100015
# (RO, ALVORADA D'OESTE)                   1100346
# (RO, ESPIGÃO D'OESTE)                    1100098
# (RO, MACHADINHO D'OESTE)                 1100130
# (RO, NOVA BRASILÂNDIA D'OESTE)           1100148
# (RO, SANTA LUZIA D'OESTE)                1100296
# (RO, SÃO FELIPE D'OESTE)                 1101484
# (RS, SANT'ANA DO LIVRAMENTO)             4317103
# (SC, GRÃO PARÁ)                          4206108
# (SC, LAURO MULLER)                       4209607
# (SC, LUIZ ALVES)                         4210001
# (SC, PRESIDENTE CASTELLO BRANCO)         4213906
# (SC, SÃO CRISTOVÃO DO SUL)               4216057
# (SE, GRACHO CARDOSO)                     2802601
# (SP, BIRITIBA-MIRIM)                     3506607
# (SP, FLORÍNIA)                           3516101
# (SP, GUAIMBÊ)                            3517307
# (SP, ITAÓCA)                             3522158
# (SP, SÃO LUIZ DO PARAITINGA)             3550001
# (TO, COUTO MAGALHÃES)                    1706001
# (TO, SÃO VALÉRIO)                        1720499
#
#                                                     nome_municipio  codigo_uf  \
# (AP, PEDRA BRANCA DO AMAPARI)              Pedra Branca do Amapari         16
# (BA, ARAÇAS)                                                Araças         29
# (BA, CAÉM)                                                    Caém         29
# (BA, IUIÚ)                                                    Iuiú         29
# (BA, MUQUÉM DE SÃO FRANCISCO)              Muquém de São Francisco         29
# (BA, QUIJINGUE)                                          Quijingue         29
# (BA, SANTA TERESINHA)                              Santa Teresinha         29
# (BA, SANTO ESTÊVÃO)                                  Santo Estêvão         29
# (CE, ITAPAJÉ)                                              Itapajé         23
# (ES, ATILIO VIVACQUA)                              Atilio Vivacqua         32
# (GO, ANHANGUERA)                                        Anhanguera         52
# (MG, PASSA-VINTE)                                      Passa-Vinte         31
# (MG, PINGO-D'ÁGUA)                                    Pingo-d'Água         31
# (MG, SEM-PEIXE)                                          Sem-Peixe         31
# (PA, ELDORADO DO CARAJÁS)                      Eldorado do Carajás         15
# (PA, SANTA IZABEL DO PARÁ)                    Santa Izabel do Pará         15
# (PB, JOCA CLAUDINO)                                  Joca Claudino         25
# (PB, QUIXABÁ)                                              Quixabá         25
# (PB, SÃO DOMINGOS)                                    São Domingos         25
# (PE, BELÉM DO SÃO FRANCISCO)                Belém do São Francisco         26
# (PE, IGUARACY)                                            Iguaracy         26
# (PE, SÃO CAETANO)                                      São Caetano         26
# (PE, SÃO VICENTE FERRER)                        São Vicente Ferrer         26
# (PI, LUÍS CORREIA)                                    Luís Correia         22
# (PR, ANTÔNIO OLINTO)                                Antônio Olinto         41
# (PR, SANTO ANTÔNIO DO CAIUÁ)                Santo Antônio do Caiuá         41
# (RJ, TRAJANO DE MORAES)                          Trajano de Moraes         33
# (RN, AUGUSTO SEVERO (CAMPO GRANDE))  Augusto Severo (Campo Grande)         24
# (RN, AÇU)                                                      Açu         24
# (RN, JANUÁRIO CICCO (BOA SAÚDE))        Januário Cicco (Boa Saúde)         24
# (RN, OLHO-D'ÁGUA DO BORGES)                  Olho-d'Água do Borges         24
# (RO, ALTA FLORESTA D'OESTE)                  Alta Floresta D'Oeste         11
# (RO, ALVORADA D'OESTE)                            Alvorada D'Oeste         11
# (RO, ESPIGÃO D'OESTE)                              Espigão D'Oeste         11
# (RO, MACHADINHO D'OESTE)                        Machadinho D'Oeste         11
# (RO, NOVA BRASILÂNDIA D'OESTE)            Nova Brasilândia D'Oeste         11
# (RO, SANTA LUZIA D'OESTE)                      Santa Luzia D'Oeste         11
# (RO, SÃO FELIPE D'OESTE)                        São Felipe D'Oeste         11
# (RS, SANT'ANA DO LIVRAMENTO)                Sant'Ana do Livramento         43
# (SC, GRÃO PARÁ)                                          Grão Pará         42
# (SC, LAURO MULLER)                                    Lauro Muller         42
# (SC, LUIZ ALVES)                                        Luiz Alves         42
# (SC, PRESIDENTE CASTELLO BRANCO)        Presidente Castello Branco         42
# (SC, SÃO CRISTOVÃO DO SUL)                    São Cristovão do Sul         42
# (SE, GRACHO CARDOSO)                                Gracho Cardoso         28
# (SP, BIRITIBA-MIRIM)                                Biritiba-Mirim         35
# (SP, FLORÍNIA)                                            Florínia         35
# (SP, GUAIMBÊ)                                              Guaimbê         35
# (SP, ITAÓCA)                                                Itaóca         35
# (SP, SÃO LUIZ DO PARAITINGA)                São Luiz do Paraitinga         35
# (TO, COUTO MAGALHÃES)                              Couto Magalhães         17
# (TO, SÃO VALÉRIO)                                      São Valério         17
#
#                                      uf               estado  capital  \
# (AP, PEDRA BRANCA DO AMAPARI)        AP                Amapá        0
# (BA, ARAÇAS)                         BA                Bahia        0
# (BA, CAÉM)                           BA                Bahia        0
# (BA, IUIÚ)                           BA                Bahia        0
# (BA, MUQUÉM DE SÃO FRANCISCO)        BA                Bahia        0
# (BA, QUIJINGUE)                      BA                Bahia        0
# (BA, SANTA TERESINHA)                BA                Bahia        0
# (BA, SANTO ESTÊVÃO)                  BA                Bahia        0
# (CE, ITAPAJÉ)                        CE                Ceará        0
# (ES, ATILIO VIVACQUA)                ES       Espírito Santo        0
# (GO, ANHANGUERA)                     GO                Goiás        0
# (MG, PASSA-VINTE)                    MG         Minas Gerais        0
# (MG, PINGO-D'ÁGUA)                   MG         Minas Gerais        0
# (MG, SEM-PEIXE)                      MG         Minas Gerais        0
# (PA, ELDORADO DO CARAJÁS)            PA                 Pará        0
# (PA, SANTA IZABEL DO PARÁ)           PA                 Pará        0
# (PB, JOCA CLAUDINO)                  PB              Paraíba        0
# (PB, QUIXABÁ)                        PB              Paraíba        0
# (PB, SÃO DOMINGOS)                   PB              Paraíba        0
# (PE, BELÉM DO SÃO FRANCISCO)         PE           Pernambuco        0
# (PE, IGUARACY)                       PE           Pernambuco        0
# (PE, SÃO CAETANO)                    PE           Pernambuco        0
# (PE, SÃO VICENTE FERRER)             PE           Pernambuco        0
# (PI, LUÍS CORREIA)                   PI                Piauí        0
# (PR, ANTÔNIO OLINTO)                 PR               Paraná        0
# (PR, SANTO ANTÔNIO DO CAIUÁ)         PR               Paraná        0
# (RJ, TRAJANO DE MORAES)              RJ       Rio de Janeiro        0
# (RN, AUGUSTO SEVERO (CAMPO GRANDE))  RN  Rio Grande do Norte        0
# (RN, AÇU)                            RN  Rio Grande do Norte        0
# (RN, JANUÁRIO CICCO (BOA SAÚDE))     RN  Rio Grande do Norte        0
# (RN, OLHO-D'ÁGUA DO BORGES)          RN  Rio Grande do Norte        0
# (RO, ALTA FLORESTA D'OESTE)          RO             Rondônia        0
# (RO, ALVORADA D'OESTE)               RO             Rondônia        0
# (RO, ESPIGÃO D'OESTE)                RO             Rondônia        0
# (RO, MACHADINHO D'OESTE)             RO             Rondônia        0
# (RO, NOVA BRASILÂNDIA D'OESTE)       RO             Rondônia        0
# (RO, SANTA LUZIA D'OESTE)            RO             Rondônia        0
# (RO, SÃO FELIPE D'OESTE)             RO             Rondônia        0
# (RS, SANT'ANA DO LIVRAMENTO)         RS    Rio Grande do Sul        0
# (SC, GRÃO PARÁ)                      SC       Santa Catarina        0
# (SC, LAURO MULLER)                   SC       Santa Catarina        0
# (SC, LUIZ ALVES)                     SC       Santa Catarina        0
# (SC, PRESIDENTE CASTELLO BRANCO)     SC       Santa Catarina        0
# (SC, SÃO CRISTOVÃO DO SUL)           SC       Santa Catarina        0
# (SE, GRACHO CARDOSO)                 SE              Sergipe        0
# (SP, BIRITIBA-MIRIM)                 SP            São Paulo        0
# (SP, FLORÍNIA)                       SP            São Paulo        0
# (SP, GUAIMBÊ)                        SP            São Paulo        0
# (SP, ITAÓCA)                         SP            São Paulo        0
# (SP, SÃO LUIZ DO PARAITINGA)         SP            São Paulo        0
# (TO, COUTO MAGALHÃES)                TO            Tocantins        0
# (TO, SÃO VALÉRIO)                    TO            Tocantins        0
#
#                                       latitude  longitude
# (AP, PEDRA BRANCA DO AMAPARI)         0.777424   -51.9503
# (BA, ARAÇAS)                        -12.220000   -38.2027
# (BA, CAÉM)                          -11.067700   -40.4320
# (BA, IUIÚ)                          -14.405400   -43.5595
# (BA, MUQUÉM DE SÃO FRANCISCO)       -12.065000   -43.5497
# (BA, QUIJINGUE)                     -10.750500   -39.2137
# (BA, SANTA TERESINHA)               -12.769700   -39.5215
# (BA, SANTO ESTÊVÃO)                 -12.428000   -39.2505
# (CE, ITAPAJÉ)                        -3.683140   -39.5855
# (ES, ATILIO VIVACQUA)               -20.913000   -41.1986
# (GO, ANHANGUERA)                    -18.333900   -48.2204
# (MG, PASSA-VINTE)                   -22.209700   -44.2344
# (MG, PINGO-D'ÁGUA)                  -19.728700   -42.4095
# (MG, SEM-PEIXE)                     -20.100800   -42.8483
# (PA, ELDORADO DO CARAJÁS)            -6.103890   -49.3553
# (PA, SANTA IZABEL DO PARÁ)           -1.296860   -48.1606
# (PB, JOCA CLAUDINO)                  -6.483620   -38.4764
# (PB, QUIXABÁ)                        -7.022400   -37.1458
# (PB, SÃO DOMINGOS)                   -6.803130   -37.9488
# (PE, BELÉM DO SÃO FRANCISCO)         -8.750460   -38.9623
# (PE, IGUARACY)                       -7.832220   -37.5082
# (PE, SÃO CAETANO)                    -8.337630   -36.2869
# (PE, SÃO VICENTE FERRER)             -7.589690   -35.4808
# (PI, LUÍS CORREIA)                   -2.884380   -41.6641
# (PR, ANTÔNIO OLINTO)                -25.980400   -50.1972
# (PR, SANTO ANTÔNIO DO CAIUÁ)        -22.735100   -52.3440
# (RJ, TRAJANO DE MORAES)             -22.063800   -42.0643
# (RN, AUGUSTO SEVERO (CAMPO GRANDE))  -5.862060   -37.3135
# (RN, AÇU)                            -5.583620   -36.9140
# (RN, JANUÁRIO CICCO (BOA SAÚDE))     -6.165660   -35.6219
# (RN, OLHO-D'ÁGUA DO BORGES)          -5.948600   -37.7047
# (RO, ALTA FLORESTA D'OESTE)         -11.928300   -61.9953
# (RO, ALVORADA D'OESTE)              -11.346300   -62.2847
# (RO, ESPIGÃO D'OESTE)               -11.526600   -61.0252
# (RO, MACHADINHO D'OESTE)             -9.443630   -61.9818
# (RO, NOVA BRASILÂNDIA D'OESTE)      -11.724700   -62.3127
# (RO, SANTA LUZIA D'OESTE)           -11.907400   -61.7777
# (RO, SÃO FELIPE D'OESTE)            -11.902300   -61.5026
# (RS, SANT'ANA DO LIVRAMENTO)        -30.877300   -55.5392
# (SC, GRÃO PARÁ)                     -28.180900   -49.2252
# (SC, LAURO MULLER)                  -28.385900   -49.4035
# (SC, LUIZ ALVES)                    -26.715100   -48.9322
# (SC, PRESIDENTE CASTELLO BRANCO)    -27.221800   -51.8089
# (SC, SÃO CRISTOVÃO DO SUL)          -27.266600   -50.4388
# (SE, GRACHO CARDOSO)                -10.225200   -37.2006
# (SP, BIRITIBA-MIRIM)                -23.569800   -46.0407
# (SP, FLORÍNIA)                      -22.868000   -50.6814
# (SP, GUAIMBÊ)                       -21.909100   -49.8986
# (SP, ITAÓCA)                        -24.639300   -48.8413
# (SP, SÃO LUIZ DO PARAITINGA)        -23.222000   -45.3109
# (TO, COUTO MAGALHÃES)                -8.284110   -49.2473
# (TO, SÃO VALÉRIO)                   -11.974300   -48.2353

# %% [markdown]
# ### Aplicando correções para o join:

# %%
def normalize(col):
    return (
        col
        .str.upper()
        .str.replace(r'[ÁÀÃ]', 'A')
        .str.replace(r'[ÉÊ]', 'E')
        .str.replace('Í', 'I')
        .str.replace('Ç', 'C')
        .str.replace(r'[ÓÔ]', 'O')
        .str.replace(r'[ÚÜ]', 'U')
        .str.replace('ELLO', 'ELO')
        .str.replace("D'O", "DO O")
        .str.replace("D'A", "DA A")
        .str.replace("T'A", "TA")
        .str.replace(' DE ', ' DO ')
        .str.replace('-', ' ')
        .str.replace(r'.+\((.+)\).*', r'\1')
    )

# %%
indexed_tse2_fixed = indexed_tse2.set_index(indexed_tse2[['UF', 'NOME']].assign(
    NOME=normalize(indexed_tse2.NOME)
).apply(tuple, axis='columns'))

indexed_tse2_fixed.head()
# Out:
#                                CÓDIGO  UF                     NOME
# (AP, AGUA BRANCA DO AMAPARI)     6084  AP   ÁGUA BRANCA DO AMAPARI
# (BA, ARACAS)                    33383  BA                   ARAÇÁS
# (BA, CAEM)                      34010  BA                     CAEM
# (BA, IUIU)                      30660  BA                     IUIU
# (BA, MUQUEM DO SAO FRANCISCO)   37460  BA  MUQUÉM DO SÃO FRANCISCO

# %%
indexed_ibge2_fixed = indexed_ibge2.set_index(indexed_ibge2[['uf', 'nome_municipio']].assign(
    nome_municipio=normalize(indexed_ibge2.nome_municipio)
).apply(tuple, axis='columns'))

indexed_ibge2_fixed.head()
# Out:
#                                codigo_ibge           nome_municipio  \
# (AP, PEDRA BRANCA DO AMAPARI)      1600154  Pedra Branca do Amapari
# (BA, ARACAS)                       2902054                   Araças
# (BA, CAEM)                         2905107                     Caém
# (BA, IUIU)                         2917334                     Iuiú
# (BA, MUQUEM DO SAO FRANCISCO)      2922250  Muquém de São Francisco
#
#                                codigo_uf  uf estado  capital   latitude  \
# (AP, PEDRA BRANCA DO AMAPARI)         16  AP  Amapá        0   0.777424
# (BA, ARACAS)                          29  BA  Bahia        0 -12.220000
# (BA, CAEM)                            29  BA  Bahia        0 -11.067700
# (BA, IUIU)                            29  BA  Bahia        0 -14.405400
# (BA, MUQUEM DO SAO FRANCISCO)         29  BA  Bahia        0 -12.065000
#
#                                longitude
# (AP, PEDRA BRANCA DO AMAPARI)   -51.9503
# (BA, ARACAS)                    -38.2027
# (BA, CAEM)                      -40.4320
# (BA, IUIU)                      -43.5595
# (BA, MUQUEM DO SAO FRANCISCO)   -43.5497

# %%
joined2 = indexed_tse2_fixed.join(indexed_ibge2_fixed, how='inner')
joined2.head()
# Out:
#                                CÓDIGO  UF                     NOME  \
# (BA, ARACAS)                    33383  BA                   ARAÇÁS
# (BA, CAEM)                      34010  BA                     CAEM
# (BA, IUIU)                      30660  BA                     IUIU
# (BA, MUQUEM DO SAO FRANCISCO)   37460  BA  MUQUÉM DO SÃO FRANCISCO
# (BA, SANTO ESTEVAO)             38750  BA            SANTO ESTEVÃO
#
#                                codigo_ibge           nome_municipio  \
# (BA, ARACAS)                       2902054                   Araças
# (BA, CAEM)                         2905107                     Caém
# (BA, IUIU)                         2917334                     Iuiú
# (BA, MUQUEM DO SAO FRANCISCO)      2922250  Muquém de São Francisco
# (BA, SANTO ESTEVAO)                2928802            Santo Estêvão
#
#                                codigo_uf  uf estado  capital  latitude  \
# (BA, ARACAS)                          29  BA  Bahia        0  -12.2200
# (BA, CAEM)                            29  BA  Bahia        0  -11.0677
# (BA, IUIU)                            29  BA  Bahia        0  -14.4054
# (BA, MUQUEM DO SAO FRANCISCO)         29  BA  Bahia        0  -12.0650
# (BA, SANTO ESTEVAO)                   29  BA  Bahia        0  -12.4280
#
#                                longitude
# (BA, ARACAS)                    -38.2027
# (BA, CAEM)                      -40.4320
# (BA, IUIU)                      -43.5595
# (BA, MUQUEM DO SAO FRANCISCO)   -43.5497
# (BA, SANTO ESTEVAO)             -39.2505

# %% [markdown]
# ### Ainda faltam:

# %%
len(indexed_tse2)- len(joined2)
# Out:
# 18

# %% [markdown]
# ### Analisando:

# %%
indexed_tse3 = indexed_tse2_fixed[~indexed_tse2_fixed.index.isin(joined2.index)]
indexed_tse3
# Out:
#                                  CÓDIGO  UF                       NOME
# (AP, AGUA BRANCA DO AMAPARI)       6084  AP     ÁGUA BRANCA DO AMAPARI
# (BA, QUINJINGUE)                  38199  BA                 QUINJINGUE
# (BA, SANTA TEREZINHA)             38695  BA            SANTA TEREZINHA
# (CE, ITAPAGE)                     14273  CE                    ITAPAGÉ
# (PA, ELDORADO DOS CARAJAS)         4120  PA       ELDORADO DOS CARAJÁS
# (PA, SANTA ISABEL DO PARA)         5290  PA       SANTA ISABEL DO PARÁ
# (PB, SANTAREM)                    19666  PB                   SANTARÉM
# (PB, SAO DOMINGOS DO POMBAL)      19429  PB     SÃO DOMINGOS DE POMBAL
# (PE, IGUARACI)                    24376  PE                   IGUARACI
# (PE, SAO CAITANO)                 25615  PE                SÃO CAITANO
# (RJ, TRAJANO DO MORAIS)           59170  RJ          TRAJANO DE MORAIS
# (RN, ASSU)                        16039  RN                       ASSÚ
# (SC, LUIS ALVES)                  81973  SC                 LUÍS ALVES
# (SE, GRACCHO CARDOSO)             31518  SE            GRACCHO CARDOSO
# (SP, FLORINEA)                    64238  SP                   FLORÍNEA
# (SP, SAO LUIS DO PARAITINGA)      71013  SP     SÃO LUÍS DO PARAITINGA
# (TO, COUTO DO MAGALHAES)          93211  TO         COUTO DE MAGALHÃES
# (TO, SAO VALERIO DA NATIVIDADE)   92681  TO  SÃO VALÉRIO DA NATIVIDADE

# %%
indexed_ibge3 = indexed_ibge2_fixed[~indexed_ibge2_fixed.index.isin(joined2.index)]
indexed_ibge3
# Out:
#                                codigo_ibge           nome_municipio  \
# (AP, PEDRA BRANCA DO AMAPARI)      1600154  Pedra Branca do Amapari
# (BA, QUIJINGUE)                    2925907                Quijingue
# (BA, SANTA TERESINHA)              2928505          Santa Teresinha
# (CE, ITAPAJE)                      2306306                  Itapajé
# (PA, ELDORADO DO CARAJAS)          1502954      Eldorado do Carajás
# (PA, SANTA IZABEL DO PARA)         1506500     Santa Izabel do Pará
# (PB, JOCA CLAUDINO)                2513653            Joca Claudino
# (PB, SAO DOMINGOS)                 2513968             São Domingos
# (PE, IGUARACY)                     2606903                 Iguaracy
# (PE, SAO CAETANO)                  2613107              São Caetano
# (RJ, TRAJANO DO MORAES)            3305901        Trajano de Moraes
# (RN, ACU)                          2400208                      Açu
# (SC, LUIZ ALVES)                   4210001               Luiz Alves
# (SE, GRACHO CARDOSO)               2802601           Gracho Cardoso
# (SP, FLORINIA)                     3516101                 Florínia
# (SP, SAO LUIZ DO PARAITINGA)       3550001   São Luiz do Paraitinga
# (TO, COUTO MAGALHAES)              1706001          Couto Magalhães
# (TO, SAO VALERIO)                  1720499              São Valério
#
#                                codigo_uf  uf               estado  capital  \
# (AP, PEDRA BRANCA DO AMAPARI)         16  AP                Amapá        0
# (BA, QUIJINGUE)                       29  BA                Bahia        0
# (BA, SANTA TERESINHA)                 29  BA                Bahia        0
# (CE, ITAPAJE)                         23  CE                Ceará        0
# (PA, ELDORADO DO CARAJAS)             15  PA                 Pará        0
# (PA, SANTA IZABEL DO PARA)            15  PA                 Pará        0
# (PB, JOCA CLAUDINO)                   25  PB              Paraíba        0
# (PB, SAO DOMINGOS)                    25  PB              Paraíba        0
# (PE, IGUARACY)                        26  PE           Pernambuco        0
# (PE, SAO CAETANO)                     26  PE           Pernambuco        0
# (RJ, TRAJANO DO MORAES)               33  RJ       Rio de Janeiro        0
# (RN, ACU)                             24  RN  Rio Grande do Norte        0
# (SC, LUIZ ALVES)                      42  SC       Santa Catarina        0
# (SE, GRACHO CARDOSO)                  28  SE              Sergipe        0
# (SP, FLORINIA)                        35  SP            São Paulo        0
# (SP, SAO LUIZ DO PARAITINGA)          35  SP            São Paulo        0
# (TO, COUTO MAGALHAES)                 17  TO            Tocantins        0
# (TO, SAO VALERIO)                     17  TO            Tocantins        0
#
#                                 latitude  longitude
# (AP, PEDRA BRANCA DO AMAPARI)   0.777424   -51.9503
# (BA, QUIJINGUE)               -10.750500   -39.2137
# (BA, SANTA TERESINHA)         -12.769700   -39.5215
# (CE, ITAPAJE)                  -3.683140   -39.5855
# (PA, ELDORADO DO CARAJAS)      -6.103890   -49.3553
# (PA, SANTA IZABEL DO PARA)     -1.296860   -48.1606
# (PB, JOCA CLAUDINO)            -6.483620   -38.4764
# (PB, SAO DOMINGOS)             -6.803130   -37.9488
# (PE, IGUARACY)                 -7.832220   -37.5082
# (PE, SAO CAETANO)              -8.337630   -36.2869
# (RJ, TRAJANO DO MORAES)       -22.063800   -42.0643
# (RN, ACU)                      -5.583620   -36.9140
# (SC, LUIZ ALVES)              -26.715100   -48.9322
# (SE, GRACHO CARDOSO)          -10.225200   -37.2006
# (SP, FLORINIA)                -22.868000   -50.6814
# (SP, SAO LUIZ DO PARAITINGA)  -23.222000   -45.3109
# (TO, COUTO MAGALHAES)          -8.284110   -49.2473
# (TO, SAO VALERIO)             -11.974300   -48.2353

# %% [markdown]
# ### Esses últimos podem ser joinados por ordem alfabética:

# %%
joined3 = indexed_tse3.reset_index(drop=True).join(indexed_ibge3.reset_index(drop=True))
joined3
# Out:
#     CÓDIGO  UF                       NOME  codigo_ibge  \
# 0     6084  AP     ÁGUA BRANCA DO AMAPARI      1600154
# 1    38199  BA                 QUINJINGUE      2925907
# 2    38695  BA            SANTA TEREZINHA      2928505
# 3    14273  CE                    ITAPAGÉ      2306306
# 4     4120  PA       ELDORADO DOS CARAJÁS      1502954
# 5     5290  PA       SANTA ISABEL DO PARÁ      1506500
# 6    19666  PB                   SANTARÉM      2513653
# 7    19429  PB     SÃO DOMINGOS DE POMBAL      2513968
# 8    24376  PE                   IGUARACI      2606903
# 9    25615  PE                SÃO CAITANO      2613107
# 10   59170  RJ          TRAJANO DE MORAIS      3305901
# 11   16039  RN                       ASSÚ      2400208
# 12   81973  SC                 LUÍS ALVES      4210001
# 13   31518  SE            GRACCHO CARDOSO      2802601
# 14   64238  SP                   FLORÍNEA      3516101
# 15   71013  SP     SÃO LUÍS DO PARAITINGA      3550001
# 16   93211  TO         COUTO DE MAGALHÃES      1706001
# 17   92681  TO  SÃO VALÉRIO DA NATIVIDADE      1720499
#
#              nome_municipio  codigo_uf  uf               estado  capital  \
# 0   Pedra Branca do Amapari         16  AP                Amapá        0
# 1                 Quijingue         29  BA                Bahia        0
# 2           Santa Teresinha         29  BA                Bahia        0
# 3                   Itapajé         23  CE                Ceará        0
# 4       Eldorado do Carajás         15  PA                 Pará        0
# 5      Santa Izabel do Pará         15  PA                 Pará        0
# 6             Joca Claudino         25  PB              Paraíba        0
# 7              São Domingos         25  PB              Paraíba        0
# 8                  Iguaracy         26  PE           Pernambuco        0
# 9               São Caetano         26  PE           Pernambuco        0
# 10        Trajano de Moraes         33  RJ       Rio de Janeiro        0
# 11                      Açu         24  RN  Rio Grande do Norte        0
# 12               Luiz Alves         42  SC       Santa Catarina        0
# 13           Gracho Cardoso         28  SE              Sergipe        0
# 14                 Florínia         35  SP            São Paulo        0
# 15   São Luiz do Paraitinga         35  SP            São Paulo        0
# 16          Couto Magalhães         17  TO            Tocantins        0
# 17              São Valério         17  TO            Tocantins        0
#
#      latitude  longitude
# 0    0.777424   -51.9503
# 1  -10.750500   -39.2137
# 2  -12.769700   -39.5215
# 3   -3.683140   -39.5855
# 4   -6.103890   -49.3553
# 5   -1.296860   -48.1606
# 6   -6.483620   -38.4764
# 7   -6.803130   -37.9488
# 8   -7.832220   -37.5082
# 9   -8.337630   -36.2869
# 10 -22.063800   -42.0643
# 11  -5.583620   -36.9140
# 12 -26.715100   -48.9322
# 13 -10.225200   -37.2006
# 14 -22.868000   -50.6814
# 15 -23.222000   -45.3109
# 16  -8.284110   -49.2473
# 17 -11.974300   -48.2353

# %% [markdown]
# ### O único estranho é Santarém -> Joca Claudino em PB, mas googlando confirmo que o município mudou de nome

# %%
final = pd.concat([joined, joined2, joined3]).sort_values(['UF', 'NOME']).reset_index(drop=True)[[
    'CÓDIGO',
    'UF',
    'NOME',
    'capital',
    'codigo_ibge',
]].rename(columns={
    'CÓDIGO': 'codigo_tse',
    'UF': 'uf',
    'NOME': 'nome_municipio',
})

final.head()
# Out:
#    codigo_tse  uf nome_municipio  capital  codigo_ibge
# 0        1120  AC     ACRELÂNDIA        0      1200013
# 1        1570  AC   ASSIS BRASIL        0      1200054
# 2        1058  AC      BRASILÉIA        0      1200104
# 3        1007  AC         BUJARI        0      1200138
# 4        1015  AC       CAPIXABA        0      1200179

# %%
final.to_csv('municipios_brasileiros_tse.csv', index=None)

with open('municipios_brasileiros_tse.json', 'w') as fp:
    fp.write(
        '[\n' +
        ','.join(final.to_json(orient='records', force_ascii=False, lines=True).split('\n')) +
        '\n]'
    )
